# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# syntax error
for z in "Alhambra" 
    print(z)
# Out:
#   File "C:\Users\MZD\AppData\Local\Temp/ipykernel_7304/3396391118.py", line 2
#     for z in "Alhambra"
#                         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
5/0

# %%
0.22*price

# %%
'1' + 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
try:
    # instructions that could raise exceptions
except:    # could be more than one
    # handling of an exception
else:
    # executed if no exceptions
finally:
    # executed anyway

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
f = open('none.txt')

# %%
import os
try:
    name ='none.txt'
    p = open(name)
except FileNotFoundError:
    print("There is no file " + name + " in folder:" + os.getcwd())

# %%
try:
    a = int( input('a:') )
    b = int( input('b:') )
    c = a/b
except ZeroDivisionError:
    print('division by zero')
except:
    print('upps, not a number')
else:
    print(a,'/',b,' = ',c)

# %%
try:
    a = int( input('a:') )
    b = int( input('b:') )
    c = a/b
except ZeroDivisionError:
    print('division by zero')
except:
    print('upps, not a number')
else:
    print(a,'/',b,' = ',c)
finally:
    print('excecuted anyway')

# %%
raise NameError('VAT')

# %%
try:
    raise NameError('Bug')
except NameError:
    print('Bug handler')
    raise   ## raise last exception again
